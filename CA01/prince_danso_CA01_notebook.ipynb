# %%
import sys
sys.executable
# Out:
# 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\python.exe'

# %%
# CA01: Exploratory Data Analysis – House Price Analysis

# import libraries

import pandas as pd
import numpy as np

# %%
# Part 1: Data Understanding – 
# Output of this part will be various visualization of the variable analysis and 
#finally the Data Quality Report that will identify the data problems that exist in this dataset

# %%
pip install autoviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting autoviz
#   Obtaining dependency information for autoviz from https://files.pythonhosted.org/packages/51/92/eea3f91d7c5788a37eb739399cf99c3b2d3b6c1f25c1b9e51a2e85f2a00a/autoviz-0.1.905-py3-none-any.whl.metadata
#   Using cached autoviz-0.1.905-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: xlrd in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from autoviz) (2.0.1)
# Collecting wordcloud (from autoviz)
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/1b/d1/a875be97f1d5c2142b1ffc65e9ffa9ef60fb183fd7c99c754cebc02a9d63/wordcloud-1.9.6-cp39-cp39-win_amd64.whl.metadata
#   Using cached wordcloud-1.9.6-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# Collecting emoji (from autoviz)
#   Obtaining dependency information for emoji from https://files.pythonhosted.org/packages/e1/5e/4b5aaaabddfacfe36ba7768817bd1f71a7a810a43705e531f3ae4c690767/emoji-2.15.0-py3-none-any.whl.metadata
#   Using cached emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting pyamg (from autoviz)
#   Using cached pyamg-5.3.0.tar.gz (4.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting scikit-learn (from autoviz)
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/fb/d8/8d603bdd26601f4b07e2363032b8565ab82eb857f93d86d0f7956fcf4523/scikit_learn-1.6.1-cp39-cp39-win_amd64.whl.metadata
#   Using cached scikit_learn-1.6.1-cp39-cp39-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: statsmodels in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from autoviz) (0.14.0)
# Collecting nltk (from autoviz)
#   Obtaining dependency information for nltk from https://files.pythonhosted.org/packages/60/90/81ac364ef94209c100e12579629dc92bf7a709a84af32f8c551b02c07e94/nltk-3.9.2-py3-none-any.whl.metadata
#   Using cached nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting textblob (from autoviz)
#   Obtaining dependency information for textblob from https://files.pythonhosted.org/packages/1e/d6/40aa5aead775582ea0cf35870e5a3f16fab4b967f1ad2debe675f673f923/textblob-0.19.0-py3-none-any.whl.metadata
#   Using cached textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting xgboost<1.7,>=0.82 (from autoviz)
#   Obtaining dependency information for xgboost<1.7,>=0.82 from https://files.pythonhosted.org/packages/24/14/d9ecb9fa86727f51bfb35f1c2b0428ebc6cd5ffde24c5e2dc583d3575a6f/xgboost-1.6.2-py3-none-win_amd64.whl.metadata
#   Using cached xgboost-1.6.2-py3-none-win_amd64.whl.metadata (1.8 kB)
# Requirement already satisfied: fsspec>=0.8.3 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from autoviz) (2023.4.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from autoviz) (4.3.0)
# Collecting pandas-dq>=1.29 (from autoviz)
#   Obtaining dependency information for pandas-dq>=1.29 from https://files.pythonhosted.org/packages/ec/96/862c60b96e2abf218eec55d3b1e409b133de83f7a4f49c047aea9eeea927/pandas_dq-1.29-py3-none-any.whl.metadata
#   Using cached pandas_dq-1.29-py3-none-any.whl.metadata (19 kB)
# Collecting numpy>=1.24.0 (from autoviz)
#   Obtaining dependency information for numpy>=1.24.0 from https://files.pythonhosted.org/packages/ea/2b/7fc9f4e7ae5b507c1a3a21f0f15ed03e794c1242ea8a242ac158beb56034/numpy-2.0.2-cp39-cp39-win_amd64.whl.metadata
#   Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl.metadata (59 kB)
# Collecting hvplot>=0.9.2 (from autoviz)
#   Obtaining dependency information for hvplot>=0.9.2 from https://files.pythonhosted.org/packages/ca/4a/3490c93a699f3d5e4d708748b494a44639dec973b609eb4e17c2d94bc733/hvplot-0.11.3-py3-none-any.whl.metadata
#   Using cached hvplot-0.11.3-py3-none-any.whl.metadata (15 kB)
# Collecting holoviews>=1.16.0 (from autoviz)
#   Obtaining dependency information for holoviews>=1.16.0 from https://files.pythonhosted.org/packages/df/67/066a1d984fa259ad7300084a70789579e104afd75fc58a1d44cda9c365d5/holoviews-1.20.2-py3-none-any.whl.metadata
#   Using cached holoviews-1.20.2-py3-none-any.whl.metadata (9.9 kB)
# Collecting panel>=1.4.0 (from autoviz)
#   Obtaining dependency information for panel>=1.4.0 from https://files.pythonhosted.org/packages/f4/e3/81303aec6a131eefa21030f2bdea12c0e0f57d1b416e7bda91841f791d20/panel-1.4.5-py3-none-any.whl.metadata
#   Using cached panel-1.4.5-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pandas>=2.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from autoviz) (2.0.2)
# Collecting matplotlib>3.7.4 (from autoviz)
#   Obtaining dependency information for matplotlib>3.7.4 from https://files.pythonhosted.org/packages/57/68/c2feb4667adbf882ffa4b3e0ac9967f848980d9f8b5bebd86644aa67ce6a/matplotlib-3.9.4-cp39-cp39-win_amd64.whl.metadata
#   Using cached matplotlib-3.9.4-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Collecting seaborn>0.12.2 (from autoviz)
#   Obtaining dependency information for seaborn>0.12.2 from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting bokeh>=3.1 (from holoviews>=1.16.0->autoviz)
#   Obtaining dependency information for bokeh>=3.1 from https://files.pythonhosted.org/packages/65/5d/e96520996607c9b894a4716ddedc447a68351b0a8729f26ac012c8e7041b/bokeh-3.4.3-py3-none-any.whl.metadata
#   Using cached bokeh-3.4.3-py3-none-any.whl.metadata (12 kB)
# Collecting colorcet (from holoviews>=1.16.0->autoviz)
#   Obtaining dependency information for colorcet from https://files.pythonhosted.org/packages/c6/c6/9963d588cc3d75d766c819e0377a168ef83cf3316a92769971527a1ad1de/colorcet-3.1.0-py3-none-any.whl.metadata
#   Using cached colorcet-3.1.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from holoviews>=1.16.0->autoviz) (21.3)
# Collecting param<3.0,>=2.0 (from holoviews>=1.16.0->autoviz)
#   Obtaining dependency information for param<3.0,>=2.0 from https://files.pythonhosted.org/packages/6a/57/2b46b199482bbaaade2f978164577cf7c2fdc2782a7caf29fabd5265a84f/param-2.2.1-py3-none-any.whl.metadata
#   Using cached param-2.2.1-py3-none-any.whl.metadata (6.6 kB)
# Collecting pyviz-comms>=2.1 (from holoviews>=1.16.0->autoviz)
#   Obtaining dependency information for pyviz-comms>=2.1 from https://files.pythonhosted.org/packages/13/5a/f8c0868199bbb231a02616286ce8a4ccb85f5387b9215510297dcfedd214/pyviz_comms-3.0.6-py3-none-any.whl.metadata
#   Using cached pyviz_comms-3.0.6-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib>3.7.4->autoviz) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib>3.7.4->autoviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib>3.7.4->autoviz) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib>3.7.4->autoviz) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib>3.7.4->autoviz) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib>3.7.4->autoviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib>3.7.4->autoviz) (2.8.2)
# Collecting importlib-resources>=3.2.0 (from matplotlib>3.7.4->autoviz)
#   Obtaining dependency information for importlib-resources>=3.2.0 from https://files.pythonhosted.org/packages/a4/ed/1f1afb2e9e7f38a545d628f864d562a5ae64fe6f7a10e28ffb9b185b4e89/importlib_resources-6.5.2-py3-none-any.whl.metadata
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages\pytz-2022.6-py3.9.egg (from pandas>=2.0->autoviz) (2022.6)
# Collecting tzdata>=2022.1 (from pandas>=2.0->autoviz)
#   Obtaining dependency information for tzdata>=2022.1 from https://files.pythonhosted.org/packages/c7/b0/003792df09decd6849a5e39c28b513c06e84436a54440380862b5aeff25d/tzdata-2025.3-py2.py3-none-any.whl.metadata
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting xyzservices>=2021.09.1 (from panel>=1.4.0->autoviz)
#   Obtaining dependency information for xyzservices>=2021.09.1 from https://files.pythonhosted.org/packages/ef/5c/2c189d18d495dd0fa3f27ccc60762bbc787eed95b9b0147266e72bb76585/xyzservices-2025.11.0-py3-none-any.whl.metadata
#   Using cached xyzservices-2025.11.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting markdown (from panel>=1.4.0->autoviz)
#   Obtaining dependency information for markdown from https://files.pythonhosted.org/packages/70/ae/44c4a6a4cbb496d93c6257954260fe3a6e91b7bed2240e5dad2a717f5111/markdown-3.9-py3-none-any.whl.metadata
#   Using cached markdown-3.9-py3-none-any.whl.metadata (5.1 kB)
# Collecting markdown-it-py (from panel>=1.4.0->autoviz)
#   Obtaining dependency information for markdown-it-py from https://files.pythonhosted.org/packages/42/d7/1ec15b46af6af88f19b8e5ffea08fa375d433c998b8a7639e76935c14f1f/markdown_it_py-3.0.0-py3-none-any.whl.metadata
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting linkify-it-py (from panel>=1.4.0->autoviz)
#   Obtaining dependency information for linkify-it-py from https://files.pythonhosted.org/packages/04/1e/b832de447dee8b582cac175871d2f6c3d5077cc56d5575cadba1fd1cccfa/linkify_it_py-2.0.3-py3-none-any.whl.metadata
#   Using cached linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting mdit-py-plugins (from panel>=1.4.0->autoviz)
#   Obtaining dependency information for mdit-py-plugins from https://files.pythonhosted.org/packages/a7/f7/7782a043553ee469c1ff49cfa1cdace2d6bf99a1f333cf38676b3ddf30da/mdit_py_plugins-0.4.2-py3-none-any.whl.metadata
#   Using cached mdit_py_plugins-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from panel>=1.4.0->autoviz) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from panel>=1.4.0->autoviz) (4.64.1)
# Requirement already satisfied: bleach in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from panel>=1.4.0->autoviz) (4.1.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from scikit-learn->autoviz) (1.7.3)
# Collecting joblib>=1.2.0 (from scikit-learn->autoviz)
#   Obtaining dependency information for joblib>=1.2.0 from https://files.pythonhosted.org/packages/7b/91/984aca2ec129e2757d1e4e3c81c3fcda9d0f85b74670a094cc443d9ee949/joblib-1.5.3-py3-none-any.whl.metadata
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->autoviz)
#   Obtaining dependency information for threadpoolctl>=3.1.0 from https://files.pythonhosted.org/packages/32/d5/f9a850d79b0851d1d4ef6456097579a9005b31fea68726a4ae5f2d82ddd9/threadpoolctl-3.6.0-py3-none-any.whl.metadata
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: click in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from nltk->autoviz) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from nltk->autoviz) (2022.7.9)
# Collecting scipy>=1.6.0 (from scikit-learn->autoviz)
#   Obtaining dependency information for scipy>=1.6.0 from https://files.pythonhosted.org/packages/3e/77/dab54fe647a08ee4253963bcd8f9cf17509c8ca64d6335141422fe2e2114/scipy-1.13.1-cp39-cp39-win_amd64.whl.metadata
#   Using cached scipy-1.13.1-cp39-cp39-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: patsy>=0.5.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from statsmodels->autoviz) (0.5.3)
# Requirement already satisfied: Jinja2>=2.9 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.0.3)
# Collecting contourpy>=1.0.1 (from matplotlib>3.7.4->autoviz)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/53/23/db9f69676308e094d3c45f20cc52e12d10d64f027541c995d89c11ad5c75/contourpy-1.3.0-cp39-cp39-win_amd64.whl.metadata
#   Using cached contourpy-1.3.0-cp39-cp39-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: PyYAML>=3.10 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.0)
# Requirement already satisfied: tornado>=6.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>3.7.4->autoviz) (3.8.0)
# Requirement already satisfied: six in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from patsy>=0.5.2->statsmodels->autoviz) (1.16.0)
# Requirement already satisfied: colorama in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from tqdm>=4.48.0->panel>=1.4.0->autoviz) (0.4.6)
# Requirement already satisfied: webencodings in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from bleach->panel>=1.4.0->autoviz) (0.5.1)
# Collecting uc-micro-py (from linkify-it-py->panel>=1.4.0->autoviz)
#   Obtaining dependency information for uc-micro-py from https://files.pythonhosted.org/packages/37/87/1f677586e8ac487e29672e4b17455758fce261de06a0d086167bb760361a/uc_micro_py-1.0.3-py3-none-any.whl.metadata
#   Using cached uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from markdown->panel>=1.4.0->autoviz) (6.0.0)
# Collecting mdurl~=0.1 (from markdown-it-py->panel>=1.4.0->autoviz)
#   Obtaining dependency information for mdurl~=0.1 from https://files.pythonhosted.org/packages/b3/38/89ba8ad64ae25be8de66a6d463314cf1eb366222074cfda9ee839c56a4b4/mdurl-0.1.2-py3-none-any.whl.metadata
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews>=1.16.0->autoviz) (2.1.1)
# Using cached autoviz-0.1.905-py3-none-any.whl (67 kB)
# Using cached holoviews-1.20.2-py3-none-any.whl (5.0 MB)
# Using cached hvplot-0.11.3-py3-none-any.whl (170 kB)
# Using cached matplotlib-3.9.4-cp39-cp39-win_amd64.whl (7.8 MB)
# Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl (15.9 MB)
# Using cached pandas_dq-1.29-py3-none-any.whl (29 kB)
# Using cached panel-1.4.5-py3-none-any.whl (24.7 MB)
# Using cached scikit_learn-1.6.1-cp39-cp39-win_amd64.whl (11.2 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached xgboost-1.6.2-py3-none-win_amd64.whl (125.4 MB)
# Using cached emoji-2.15.0-py3-none-any.whl (608 kB)
# Using cached nltk-3.9.2-py3-none-any.whl (1.5 MB)
# Using cached textblob-0.19.0-py3-none-any.whl (624 kB)
# Using cached wordcloud-1.9.6-cp39-cp39-win_amd64.whl (306 kB)
# Using cached bokeh-3.4.3-py3-none-any.whl (7.0 MB)
# Using cached colorcet-3.1.0-py3-none-any.whl (260 kB)
# Using cached contourpy-1.3.0-cp39-cp39-win_amd64.whl (211 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached param-2.2.1-py3-none-any.whl (119 kB)
# Using cached pyviz_comms-3.0.6-py3-none-any.whl (84 kB)
# Using cached scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Using cached xyzservices-2025.11.0-py3-none-any.whl (93 kB)
# Using cached linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Using cached markdown-3.9-py3-none-any.whl (107 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdit_py_plugins-0.4.2-py3-none-any.whl (55 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# Building wheels for collected packages: pyamg
#   Building wheel for pyamg (pyproject.toml): started
#   Building wheel for pyamg (pyproject.toml): finished with status 'error'
# Failed to build pyamg
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   Building wheel for pyamg (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [149 lines of output]
#   C:\Users\pdans\AppData\Local\Temp\pip-build-env-5trvp53n\overlay\Lib\site-packages\setuptools_scm\git.py:310: UserWarning: git archive did not support describe output
#     warnings.warn("git archive did not support describe output")
#   C:\Users\pdans\AppData\Local\Temp\pip-build-env-5trvp53n\overlay\Lib\site-packages\setuptools_scm\git.py:328: UserWarning: unprocessed git archival found (no export subst applied)
#     warnings.warn("unprocessed git archival found (no export subst applied)")
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-39
#   creating build\lib.win-amd64-cpython-39\pyamg
#   copying pyamg\blackbox.py -> build\lib.win-amd64-cpython-39\pyamg
#   copying pyamg\graph.py -> build\lib.win-amd64-cpython-39\pyamg
#   copying pyamg\graph_ref.py -> build\lib.win-amd64-cpython-39\pyamg
#   copying pyamg\multilevel.py -> build\lib.win-amd64-cpython-39\pyamg
#   copying pyamg\strength.py -> build\lib.win-amd64-cpython-39\pyamg
#   copying pyamg\version.py -> build\lib.win-amd64-cpython-39\pyamg
#   copying pyamg\__init__.py -> build\lib.win-amd64-cpython-39\pyamg
#   creating build\lib.win-amd64-cpython-39\pyamg\aggregation
#   copying pyamg\aggregation\adaptive.py -> build\lib.win-amd64-cpython-39\pyamg\aggregation
#   copying pyamg\aggregation\aggregate.py -> build\lib.win-amd64-cpython-39\pyamg\aggregation
#   copying pyamg\aggregation\aggregation.py -> build\lib.win-amd64-cpython-39\pyamg\aggregation
#   copying pyamg\aggregation\pairwise.py -> build\lib.win-amd64-cpython-39\pyamg\aggregation
#   copying pyamg\aggregation\rootnode.py -> build\lib.win-amd64-cpython-39\pyamg\aggregation
#   copying pyamg\aggregation\smooth.py -> build\lib.win-amd64-cpython-39\pyamg\aggregation
#   copying pyamg\aggregation\tentative.py -> build\lib.win-amd64-cpython-39\pyamg\aggregation
#   copying pyamg\aggregation\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\aggregation
#   creating build\lib.win-amd64-cpython-39\pyamg\amg_core
#   copying pyamg\amg_core\bindthem.py -> build\lib.win-amd64-cpython-39\pyamg\amg_core
#   copying pyamg\amg_core\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\amg_core
#   creating build\lib.win-amd64-cpython-39\pyamg\classical
#   copying pyamg\classical\air.py -> build\lib.win-amd64-cpython-39\pyamg\classical
#   copying pyamg\classical\classical.py -> build\lib.win-amd64-cpython-39\pyamg\classical
#   copying pyamg\classical\cr.py -> build\lib.win-amd64-cpython-39\pyamg\classical
#   copying pyamg\classical\interpolate.py -> build\lib.win-amd64-cpython-39\pyamg\classical
#   copying pyamg\classical\split.py -> build\lib.win-amd64-cpython-39\pyamg\classical
#   copying pyamg\classical\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\classical
#   creating build\lib.win-amd64-cpython-39\pyamg\gallery
#   copying pyamg\gallery\advection.py -> build\lib.win-amd64-cpython-39\pyamg\gallery
#   copying pyamg\gallery\demo.py -> build\lib.win-amd64-cpython-39\pyamg\gallery
#   copying pyamg\gallery\diffusion.py -> build\lib.win-amd64-cpython-39\pyamg\gallery
#   copying pyamg\gallery\elasticity.py -> build\lib.win-amd64-cpython-39\pyamg\gallery
#   copying pyamg\gallery\example.py -> build\lib.win-amd64-cpython-39\pyamg\gallery
#   copying pyamg\gallery\fem.py -> build\lib.win-amd64-cpython-39\pyamg\gallery
#   copying pyamg\gallery\laplacian.py -> build\lib.win-amd64-cpython-39\pyamg\gallery
#   copying pyamg\gallery\mesh.py -> build\lib.win-amd64-cpython-39\pyamg\gallery
#   copying pyamg\gallery\random_sparse.py -> build\lib.win-amd64-cpython-39\pyamg\gallery
#   copying pyamg\gallery\stencil.py -> build\lib.win-amd64-cpython-39\pyamg\gallery
#   copying pyamg\gallery\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\gallery
#   creating build\lib.win-amd64-cpython-39\pyamg\krylov
#   copying pyamg\krylov\_bicgstab.py -> build\lib.win-amd64-cpython-39\pyamg\krylov
#   copying pyamg\krylov\_cg.py -> build\lib.win-amd64-cpython-39\pyamg\krylov
#   copying pyamg\krylov\_cgne.py -> build\lib.win-amd64-cpython-39\pyamg\krylov
#   copying pyamg\krylov\_cgnr.py -> build\lib.win-amd64-cpython-39\pyamg\krylov
#   copying pyamg\krylov\_cr.py -> build\lib.win-amd64-cpython-39\pyamg\krylov
#   copying pyamg\krylov\_fgmres.py -> build\lib.win-amd64-cpython-39\pyamg\krylov
#   copying pyamg\krylov\_gmres.py -> build\lib.win-amd64-cpython-39\pyamg\krylov
#   copying pyamg\krylov\_gmres_householder.py -> build\lib.win-amd64-cpython-39\pyamg\krylov
#   copying pyamg\krylov\_gmres_mgs.py -> build\lib.win-amd64-cpython-39\pyamg\krylov
#   copying pyamg\krylov\_minimal_residual.py -> build\lib.win-amd64-cpython-39\pyamg\krylov
#   copying pyamg\krylov\_steepest_descent.py -> build\lib.win-amd64-cpython-39\pyamg\krylov
#   copying pyamg\krylov\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\krylov
#   creating build\lib.win-amd64-cpython-39\pyamg\relaxation
#   copying pyamg\relaxation\chebyshev.py -> build\lib.win-amd64-cpython-39\pyamg\relaxation
#   copying pyamg\relaxation\relaxation.py -> build\lib.win-amd64-cpython-39\pyamg\relaxation
#   copying pyamg\relaxation\smoothing.py -> build\lib.win-amd64-cpython-39\pyamg\relaxation
#   copying pyamg\relaxation\utils.py -> build\lib.win-amd64-cpython-39\pyamg\relaxation
#   copying pyamg\relaxation\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\relaxation
#   creating build\lib.win-amd64-cpython-39\pyamg\tests
#   copying pyamg\tests\test_amg_core_linalg.py -> build\lib.win-amd64-cpython-39\pyamg\tests
#   copying pyamg\tests\test_blackbox.py -> build\lib.win-amd64-cpython-39\pyamg\tests
#   copying pyamg\tests\test_clustering.py -> build\lib.win-amd64-cpython-39\pyamg\tests
#   copying pyamg\tests\test_floyd.py -> build\lib.win-amd64-cpython-39\pyamg\tests
#   copying pyamg\tests\test_graph.py -> build\lib.win-amd64-cpython-39\pyamg\tests
#   copying pyamg\tests\test_lloyd.py -> build\lib.win-amd64-cpython-39\pyamg\tests
#   copying pyamg\tests\test_multilevel.py -> build\lib.win-amd64-cpython-39\pyamg\tests
#   copying pyamg\tests\test_strength.py -> build\lib.win-amd64-cpython-39\pyamg\tests
#   copying pyamg\tests\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\tests
#   creating build\lib.win-amd64-cpython-39\pyamg\util
#   copying pyamg\util\bsr_utils.py -> build\lib.win-amd64-cpython-39\pyamg\util
#   copying pyamg\util\linalg.py -> build\lib.win-amd64-cpython-39\pyamg\util
#   copying pyamg\util\params.py -> build\lib.win-amd64-cpython-39\pyamg\util
#   copying pyamg\util\utils.py -> build\lib.win-amd64-cpython-39\pyamg\util
#   copying pyamg\util\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\util
#   creating build\lib.win-amd64-cpython-39\pyamg\vis
#   copying pyamg\vis\aggviz.py -> build\lib.win-amd64-cpython-39\pyamg\vis
#   copying pyamg\vis\vis_coarse.py -> build\lib.win-amd64-cpython-39\pyamg\vis
#   copying pyamg\vis\vtk_writer.py -> build\lib.win-amd64-cpython-39\pyamg\vis
#   copying pyamg\vis\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\vis
#   creating build\lib.win-amd64-cpython-39\pyamg\aggregation\tests
#   copying pyamg\aggregation\tests\test_adaptive.py -> build\lib.win-amd64-cpython-39\pyamg\aggregation\tests
#   copying pyamg\aggregation\tests\test_aggregate.py -> build\lib.win-amd64-cpython-39\pyamg\aggregation\tests
#   copying pyamg\aggregation\tests\test_aggregation.py -> build\lib.win-amd64-cpython-39\pyamg\aggregation\tests
#   copying pyamg\aggregation\tests\test_pairwise.py -> build\lib.win-amd64-cpython-39\pyamg\aggregation\tests
#   copying pyamg\aggregation\tests\test_rootnode.py -> build\lib.win-amd64-cpython-39\pyamg\aggregation\tests
#   copying pyamg\aggregation\tests\test_smooth.py -> build\lib.win-amd64-cpython-39\pyamg\aggregation\tests
#   copying pyamg\aggregation\tests\test_tentative.py -> build\lib.win-amd64-cpython-39\pyamg\aggregation\tests
#   copying pyamg\aggregation\tests\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\aggregation\tests
#   creating build\lib.win-amd64-cpython-39\pyamg\amg_core\tests
#   copying pyamg\amg_core\tests\test_bind_examples.py -> build\lib.win-amd64-cpython-39\pyamg\amg_core\tests
#   copying pyamg\amg_core\tests\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\amg_core\tests
#   creating build\lib.win-amd64-cpython-39\pyamg\classical\tests
#   copying pyamg\classical\tests\test_air.py -> build\lib.win-amd64-cpython-39\pyamg\classical\tests
#   copying pyamg\classical\tests\test_classical.py -> build\lib.win-amd64-cpython-39\pyamg\classical\tests
#   copying pyamg\classical\tests\test_cr.py -> build\lib.win-amd64-cpython-39\pyamg\classical\tests
#   copying pyamg\classical\tests\test_split.py -> build\lib.win-amd64-cpython-39\pyamg\classical\tests
#   copying pyamg\classical\tests\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\classical\tests
#   creating build\lib.win-amd64-cpython-39\pyamg\gallery\tests
#   copying pyamg\gallery\tests\test_advection.py -> build\lib.win-amd64-cpython-39\pyamg\gallery\tests
#   copying pyamg\gallery\tests\test_diffusion.py -> build\lib.win-amd64-cpython-39\pyamg\gallery\tests
#   copying pyamg\gallery\tests\test_elasticity.py -> build\lib.win-amd64-cpython-39\pyamg\gallery\tests
#   copying pyamg\gallery\tests\test_example.py -> build\lib.win-amd64-cpython-39\pyamg\gallery\tests
#   copying pyamg\gallery\tests\test_fem.py -> build\lib.win-amd64-cpython-39\pyamg\gallery\tests
#   copying pyamg\gallery\tests\test_laplacian.py -> build\lib.win-amd64-cpython-39\pyamg\gallery\tests
#   copying pyamg\gallery\tests\test_mesh.py -> build\lib.win-amd64-cpython-39\pyamg\gallery\tests
#   copying pyamg\gallery\tests\test_stencil.py -> build\lib.win-amd64-cpython-39\pyamg\gallery\tests
#   copying pyamg\gallery\tests\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\gallery\tests
#   creating build\lib.win-amd64-cpython-39\pyamg\krylov\tests
#   copying pyamg\krylov\tests\test_krylov.py -> build\lib.win-amd64-cpython-39\pyamg\krylov\tests
#   copying pyamg\krylov\tests\test_scipy.py -> build\lib.win-amd64-cpython-39\pyamg\krylov\tests
#   copying pyamg\krylov\tests\test_simple_iterations.py -> build\lib.win-amd64-cpython-39\pyamg\krylov\tests
#   copying pyamg\krylov\tests\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\krylov\tests
#   creating build\lib.win-amd64-cpython-39\pyamg\relaxation\tests
#   copying pyamg\relaxation\tests\test_relaxation.py -> build\lib.win-amd64-cpython-39\pyamg\relaxation\tests
#   copying pyamg\relaxation\tests\test_smoothing.py -> build\lib.win-amd64-cpython-39\pyamg\relaxation\tests
#   copying pyamg\relaxation\tests\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\relaxation\tests
#   creating build\lib.win-amd64-cpython-39\pyamg\util\tests
#   copying pyamg\util\tests\test_bsr_utils.py -> build\lib.win-amd64-cpython-39\pyamg\util\tests
#   copying pyamg\util\tests\test_linalg.py -> build\lib.win-amd64-cpython-39\pyamg\util\tests
#   copying pyamg\util\tests\test_utils.py -> build\lib.win-amd64-cpython-39\pyamg\util\tests
#   copying pyamg\util\tests\test_warn.py -> build\lib.win-amd64-cpython-39\pyamg\util\tests
#   copying pyamg\util\tests\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\util\tests
#   creating build\lib.win-amd64-cpython-39\pyamg\vis\tests
#   copying pyamg\vis\tests\test_vis.py -> build\lib.win-amd64-cpython-39\pyamg\vis\tests
#   copying pyamg\vis\tests\test_vtu.py -> build\lib.win-amd64-cpython-39\pyamg\vis\tests
#   copying pyamg\vis\tests\__init__.py -> build\lib.win-amd64-cpython-39\pyamg\vis\tests
#   creating build\lib.win-amd64-cpython-39\pyamg\gallery\example_data
#   copying pyamg\gallery\example_data\airfoil.mat -> build\lib.win-amd64-cpython-39\pyamg\gallery\example_data
#   copying pyamg\gallery\example_data\bar.mat -> build\lib.win-amd64-cpython-39\pyamg\gallery\example_data
#   copying pyamg\gallery\example_data\helmholtz_2D.mat -> build\lib.win-amd64-cpython-39\pyamg\gallery\example_data
#   copying pyamg\gallery\example_data\knot.mat -> build\lib.win-amd64-cpython-39\pyamg\gallery\example_data
#   copying pyamg\gallery\example_data\local_disc_galerkin_diffusion.mat -> build\lib.win-amd64-cpython-39\pyamg\gallery\example_data
#   copying pyamg\gallery\example_data\recirc_flow.mat -> build\lib.win-amd64-cpython-39\pyamg\gallery\example_data
#   copying pyamg\gallery\example_data\unit_cube.mat -> build\lib.win-amd64-cpython-39\pyamg\gallery\example_data
#   copying pyamg\gallery\example_data\unit_square.mat -> build\lib.win-amd64-cpython-39\pyamg\gallery\example_data
#   creating build\lib.win-amd64-cpython-39\pyamg\gallery\mesh_data
#   copying pyamg\gallery\mesh_data\square_mesh.npz -> build\lib.win-amd64-cpython-39\pyamg\gallery\mesh_data
#   running build_ext
#   building 'pyamg.amg_core.air' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pyamg
# ERROR: Could not build wheels for pyamg, which is required to install pyproject.toml-based projects

# %%
# import Auto EDA AutoViz tool

from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22816\685833962.py in <cell line: 3>()
#       1 # import Auto EDA AutoViz tool
#       2
# ----> 3 from autoviz.AutoViz_Class import AutoViz_Class
#       4 AV = AutoViz_Class()
#
# ModuleNotFoundError: No module named 'autoviz'

# %%
housePrice_df = pd.read_csv('house-price-train.csv')
print(housePrice_df.shape)
housePrice_df.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
# Part 2: In this part you will fix the data problems identified in the Data Quality Report learning from python techniques and 
# code samples shared with you (links provided in the slide deck).

# %%
# Part 3: For this part, ONLY do the “collinearity” visualization and identification of the features that needs to be dropped (feature selection), 
# if any. You DO NOT NEED to do the “class imbalance” step, as this has not been covered yet in class.
