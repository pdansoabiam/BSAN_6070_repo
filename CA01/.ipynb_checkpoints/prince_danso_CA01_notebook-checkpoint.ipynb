# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\pdans\\anaconda3\\python.exe'

# %%
# CA01: Exploratory Data Analysis – House Price Analysis

# import libraries

import pandas as pd
import numpy as np

# %%
# Part 1: Data Understanding – 
# Output of this part will be various visualization of the variable analysis and 
#finally the Data Quality Report that will identify the data problems that exist in this dataset

# %%
pip install autoviz
# Out:
# Requirement already satisfied: autoviz in c:\users\pdans\anaconda3\lib\site-packages (0.1.905)
# Requirement already satisfied: xlrd in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (2.0.2)
# Requirement already satisfied: wordcloud in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (1.9.6)
# Requirement already satisfied: emoji in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (2.15.0)
# Requirement already satisfied: pyamg in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (5.3.0)
# Requirement already satisfied: scikit-learn in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (1.6.1)
# Requirement already satisfied: statsmodels in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (0.14.4)
# Requirement already satisfied: nltk in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (3.9.1)
# Requirement already satisfied: textblob in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (0.19.0)
# Requirement already satisfied: xgboost<1.7,>=0.82 in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (1.6.2)
# Requirement already satisfied: fsspec>=0.8.3 in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (2025.3.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (4.12.2)
# Requirement already satisfied: pandas-dq>=1.29 in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (1.29)
# Requirement already satisfied: numpy>=1.24.0 in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (2.1.3)
# Requirement already satisfied: hvplot>=0.9.2 in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (0.11.3)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (1.20.2)
# Requirement already satisfied: panel>=1.4.0 in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (1.7.0)
# Requirement already satisfied: pandas>=2.0 in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (2.2.3)
# Requirement already satisfied: matplotlib>3.7.4 in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (3.10.0)
# Requirement already satisfied: seaborn>0.12.2 in c:\users\pdans\anaconda3\lib\site-packages (from autoviz) (0.13.2)
# Requirement already satisfied: scipy in c:\users\pdans\anaconda3\lib\site-packages (from xgboost<1.7,>=0.82->autoviz) (1.15.3)
# Requirement already satisfied: bokeh>=3.1 in c:\users\pdans\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.6.2)
# Requirement already satisfied: colorcet in c:\users\pdans\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.1.0)
# Requirement already satisfied: packaging in c:\users\pdans\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (24.2)
# Requirement already satisfied: param<3.0,>=2.0 in c:\users\pdans\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (2.2.0)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\pdans\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.0.2)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\pdans\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in c:\users\pdans\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (1.3.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\pdans\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (11.3.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\pdans\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\pdans\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.5.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\pdans\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pdans\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.0.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\pdans\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pdans\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pdans\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pdans\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pdans\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pdans\anaconda3\lib\site-packages (from pandas>=2.0->autoviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pdans\anaconda3\lib\site-packages (from pandas>=2.0->autoviz) (2025.2)
# Requirement already satisfied: bleach in c:\users\pdans\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (6.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\pdans\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (2.0.0)
# Requirement already satisfied: markdown in c:\users\pdans\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (3.8)
# Requirement already satisfied: markdown-it-py in c:\users\pdans\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\pdans\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (0.3.0)
# Requirement already satisfied: requests in c:\users\pdans\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\pdans\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (4.67.1)
# Requirement already satisfied: six>=1.5 in c:\users\pdans\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>3.7.4->autoviz) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\pdans\anaconda3\lib\site-packages (from scikit-learn->autoviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\pdans\anaconda3\lib\site-packages (from scikit-learn->autoviz) (3.5.0)
# Requirement already satisfied: webencodings in c:\users\pdans\anaconda3\lib\site-packages (from bleach->panel>=1.4.0->autoviz) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\pdans\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.4.0->autoviz) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pdans\anaconda3\lib\site-packages (from markdown-it-py->panel>=1.4.0->autoviz) (0.1.0)
# Requirement already satisfied: click in c:\users\pdans\anaconda3\lib\site-packages (from nltk->autoviz) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\pdans\anaconda3\lib\site-packages (from nltk->autoviz) (2024.11.6)
# Requirement already satisfied: colorama in c:\users\pdans\anaconda3\lib\site-packages (from click->nltk->autoviz) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pdans\anaconda3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pdans\anaconda3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pdans\anaconda3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pdans\anaconda3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2026.1.4)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\pdans\anaconda3\lib\site-packages (from statsmodels->autoviz) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import Auto EDA AutoViz tool

from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
# import house price as dataframe

housePrice_df = pd.read_csv('house-price-train.csv')
print(housePrice_df.shape)
housePrice_df.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1      60        RL        65.0        8450   Pave    NaN    Reg
# 1   2      20        RL        80.0        9600   Pave    NaN    Reg
# 2   3      60        RL        68.0       11250   Pave    NaN    IR1
# 3   4      70        RL        60.0        9550   Pave    NaN    IR1
# 4   5      60        RL        84.0       14260   Pave    NaN    IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0      Lvl      AllPub    Inside      Gtl      CollgCr       Norm
# 1      Lvl      AllPub       FR2      Gtl      Veenker      Feedr
# 2      Lvl      AllPub    Inside      Gtl      CollgCr       Norm
# 3      Lvl      AllPub    Corner      Gtl      Crawfor       Norm
# 4      Lvl      AllPub       FR2      Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0    Norm      1Fam     2Story         7            5         2003
# 1    Norm      1Fam     1Story         6            8         1976
# 2    Norm      1Fam     2Story         7            5         2001
# 3    Norm      1Fam     2Story         7            5         1915
# 4    Norm      1Fam     2Story         8            5         2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0      2003        Gable   CompShg    VinylSd     VinylSd    BrkFace
# 1      1976        Gable   CompShg    MetalSd     MetalSd        NaN
# 2      2002        Gable   CompShg    VinylSd     VinylSd    BrkFace
# 3      1970        Gable   CompShg    Wd Sdng     Wd Shng        NaN
# 4      2000        Gable   CompShg    VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0     196.0       Gd        TA       PConc      Gd       TA         No
# 1       0.0       TA        TA      CBlock      Gd       TA         Gd
# 2     162.0       Gd        TA       PConc      Gd       TA         Mn
# 3       0.0       TA        TA      BrkTil      TA       Gd         No
# 4     350.0       Gd        TA       PConc      Gd       TA         Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0      GLQ          706         Unf           0         150         856
# 1      ALQ          978         Unf           0         284        1262
# 2      GLQ          486         Unf           0         434         920
# 3      ALQ          216         Unf           0         540         756
# 4      GLQ          655         Unf           0         490        1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0   GasA      Ex         Y        SBrkr       856       854          0
# 1   GasA      Ex         Y        SBrkr      1262         0          0
# 2   GasA      Ex         Y        SBrkr       920       866          0
# 3   GasA      Gd         Y        SBrkr       961       756          0
# 4   GasA      Ex         Y        SBrkr      1145      1053          0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0    1710           1             0           2         1           3
# 1    1262           0             1           2         0           3
# 2    1786           1             0           2         1           3
# 3    1717           1             0           1         0           3
# 4    2198           1             0           2         1           4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0        1           Gd            8          Typ          0          NaN
# 1        1           TA            6          Typ          1           TA
# 2        1           Gd            6          Typ          1           TA
# 3        1           Gd            7          Typ          1           Gd
# 4        1           Gd            9          Typ          1           TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0   Attchd      2003.0         RFn           2          548        TA
# 1   Attchd      1976.0         RFn           2          460        TA
# 2   Attchd      2001.0         RFn           2          608        TA
# 3   Detchd      1998.0         Unf           3          642        TA
# 4   Attchd      2000.0         RFn           3          836        TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0     TA          Y            0         61              0           0
# 1     TA          Y          298          0              0           0
# 2     TA          Y            0         42              0           0
# 3     TA          Y            0         35            272           0
# 4     TA          Y          192         84              0           0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0       0           0      NaN    NaN      NaN        0        2     2008
# 1       0           0      NaN    NaN      NaN        0        5     2007
# 2       0           0      NaN    NaN      NaN        0        9     2008
# 3       0           0      NaN    NaN      NaN        0        2     2006
# 4       0           0      NaN    NaN      NaN        0       12     2008
#
#   SaleType SaleCondition  SalePrice
# 0    WD         Normal     208500
# 1    WD         Normal     181500
# 2    WD         Normal     223500
# 3    WD        Abnorml     140000
# 4    WD         Normal     250000

# %%
sep = ','
dft = AV.AutoViz(filename="",sep=sep, depVar='SalePrice', dfte=housePrice_df, header=0, verbose=2, 
                 lowess=False, chart_format='svg', save_plot_dir=None)
# Out:
# Shape of your Data Set loaded: (1460, 81)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#   Printing up to 30 columns (max) in each category:
#     Numeric Columns : ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
#     Integer-Categorical Columns: ['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal']
#     String-Categorical Columns: ['MSZoning', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType']
#     Factor-Categorical Columns: []
#     String-Boolean Columns: ['Street', 'Utilities', 'CentralAir']
#     Numeric-Boolean Columns: []
#     Discrete String Columns: []
#     NLP text Columns: []
#     Date Time Columns: ['YearRemodAdd', 'YrSold']
#     ID Columns: ['Id']
#     Columns that will not be considered in modeling: ['Alley', 'PoolQC', 'MiscFeature']
#     80 Predictors classified...
#         4 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Id', 'Alley', 'PoolQC', 'MiscFeature']
#
# ################ Regression problem #####################
# Number of variables = 76 exceeds limit, finding top 30 variables through XGBoost
#     No categorical feature reduction done. All 73 Categorical vars selected
#     Removing correlated variables from 3 numerics using SULO method
# Selecting all (3) variables since none of them are highly correlated...
#     Adding 73 categorical variables to reduced numeric variables  of 3
# ############## F E A T U R E   S E L E C T I O N  ####################
# Current number of predictors = 76
#     Finding Important Features using Boosted Trees algorithm...
#         using 76 variables...
# Finding top features using XGB is crashing. Continuing with all predictors...
#     Since number of features selected is greater than max columns analyzed, limiting to 30 variables
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     30 Predictors classified...
#     No variables removed since no ID or low-information variables found in data
#     List of variables removed: []
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_a5e42_row0_col0, #T_a5e42_row0_col2, #T_a5e42_row0_col3, #T_a5e42_row0_col4, #T_a5e42_row0_col5, #T_a5e42_row1_col0, #T_a5e42_row1_col2, #T_a5e42_row1_col3, #T_a5e42_row1_col4, #T_a5e42_row1_col5, #T_a5e42_row2_col0, #T_a5e42_row2_col2, #T_a5e42_row2_col3, #T_a5e42_row2_col4, #T_a5e42_row2_col5, #T_a5e42_row3_col0, #T_a5e42_row3_col2, #T_a5e42_row3_col3, #T_a5e42_row3_col4, #T_a5e42_row3_col5, #T_a5e42_row4_col0, #T_a5e42_row4_col2, #T_a5e42_row4_col3, #T_a5e42_row4_col4, #T_a5e42_row4_col5, #T_a5e42_row5_col0, #T_a5e42_row5_col2, #T_a5e42_row5_col3, #T_a5e42_row5_col4, #T_a5e42_row5_col5, #T_a5e42_row6_col0, #T_a5e42_row6_col2, #T_a5e42_row6_col3, #T_a5e42_row6_col4, #T_a5e42_row6_col5, #T_a5e42_row7_col0, #T_a5e42_row7_col2, #T_a5e42_row7_col3, #T_a5e42_row7_col4, #T_a5e42_row7_col5, #T_a5e42_row8_col0, #T_a5e42_row8_col2, #T_a5e42_row8_col3, #T_a5e42_row8_col4, #T_a5e42_row8_col5, #T_a5e42_row9_col0, #T_a5e42_row9_col2, #T_a5e42_row9_col3, #T_a5e42_row9_col4, #T_a5e42_row9_col5, #T_a5e42_row10_col0, #T_a5e42_row10_col2, #T_a5e42_row10_col3, #T_a5e42_row10_col4, #T_a5e42_row10_col5, #T_a5e42_row11_col0, #T_a5e42_row11_col2, #T_a5e42_row11_col3, #T_a5e42_row11_col4, #T_a5e42_row11_col5, #T_a5e42_row12_col0, #T_a5e42_row12_col2, #T_a5e42_row12_col3, #T_a5e42_row12_col4, #T_a5e42_row12_col5, #T_a5e42_row13_col0, #T_a5e42_row13_col2, #T_a5e42_row13_col3, #T_a5e42_row13_col4, #T_a5e42_row13_col5, #T_a5e42_row14_col0, #T_a5e42_row14_col2, #T_a5e42_row14_col3, #T_a5e42_row14_col4, #T_a5e42_row14_col5, #T_a
col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_a5e42_row25_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_a5e42_row29_col1 {
#   background-color: #ffeee7;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_a5e42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5e42_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_a5e42_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_a5e42_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_a5e42_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_a5e42_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_a5e42_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5e42_level0_row0" class="row_heading level0 row0" >LotFrontage</th>
#       <td id="T_a5e42_row0_col0" class="data row0 col0" >float64</td>
#       <td id="T_a5e42_row0_col1" class="data row0 col1" >17.739726</td>
#       <td id="T_a5e42_row0_col2" class="data row0 col2" >NA</td>
#       <td id="T_a5e42_row0_col3" class="data row0 col3" >21.000000</td>
#       <td id="T_a5e42_row0_col4" class="data row0 col4" >313.000000</td>
#       <td id="T_a5e42_row0_col5" class="data row0 col5" >259 missing values. Impute them with mean, median, mode, or a constant value such as 123., Column has 88 outliers greater than upper bound (111.50) or lower than lower bound(27.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_a5e42_level0_row1" class="row_heading level0 row1" >MasVnrArea</th>
#       <td id="T_a5e42_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_a5e42_row1_col1" class="data row1 col1" >0.547945</td>
#       <td id="T_a5e42_row1_col2" class="data row1 col2" >NA</td>
#       <td id="T_a5e42_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_a5e42_row1_col4" class="data row1 col4" >1600.000000</td>
#       <td id="T_a5e42_row1_col5" class="data row1 col5" >8 missing values. Impute them with mean, median, mode, or a constant value such as 123., Column has 96 outliers greater than upper bound (415.00) or lower than lower bound(-249.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_a5e42_level0_row2" class="row_heading level0 row2" >GarageYrBlt</th>
#       <td id="T_a5e42_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_a5e42_row2_col1" class="data row2 col1" >5.547945</td>
#       <td id="T_a5e42_row2_col2" class="data row2 col2" >NA</td>
#       <td id="T_a5e42_row2_col3" class="data row2 col3" >1900.000000</td>
#       <td id="T_a5e42_row2_col4" class="data row2 col4" >2010.000000</td>
#       <td id="T_a5e42_row2_col5" class="data row2 col5" >81 missing values. Impute them with mean, median, mode, or a constant value such as 123.</td>
#     </tr>
#     <tr>
#       <th id="T_a5e42_level0_row3" class="row_heading level0 row3" >MSSubClass</th>
#       <td id="T_a5e42_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_a5e42_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_a5e42_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_a5e42_row3_col3" class="data row3 col3" >20.000000</td>
#       <td id="T_a5e42_row3_col4" class="data row3 col4" >190.000000</td>
#       <td id="T_a5e42_row3_col5" class="data row3 col5" >Column has 103 outliers greater than upper bound (145.00) or lower than lower bound(-55.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_a5e42_level0_row4" class="row_heading level0 row4" >MSZoning</th>
#       <td id="T_a5e42_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_a5e42_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_a5e42_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_a5e42_row4_co
# Number of All Scatter Plots = 6
# Could not draw some Time Series plots. agg function failed [how->mean,dtype->object]
# All Plots are saved in .\AutoViz_Plots\SalePrice
# Time to run AutoViz = 18 seconds

# %%
# Show visualization since Jupyter environment is rather saving in a folder

import matplotlib.pyplot as plt
plt.plot([1,2,3],[1,4,9])
plt.title("Test plot")
plt.show()

# %%
# How to open the folder directly from Jupyter
# import os
# os.listdir("AutoViz_Plots/SalePrice")

# %%
# Part 2: In this part you will fix the data problems identified in the Data Quality Report learning from python techniques and 
# code samples shared with you (links provided in the slide deck).

# %%
# Part 3: For this part, ONLY do the “collinearity” visualization and identification of the features that needs to be dropped (feature selection), 
# if any. You DO NOT NEED to do the “class imbalance” step, as this has not been covered yet in class.
